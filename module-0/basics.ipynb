# %%
#importing ollama
from langchain_ollama import  ChatOllama

# %%
llm = ChatOllama(model="llama3.1",tempreture=0)
llm2 = ChatOllama(model="llama3-groq-tool-use",tempreture=0)

# %%
for token in llm.stream("why the sky is blue"): 
    print(token.content, flush=True, end="")
# Out:
# One of the most popular and enduring questions!
#
# The reason why the sky appears blue to our eyes is due to a combination of physics and optics. Here's a simplified explanation:
#
# **Scattering of light**: When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen (N2) and oxygen (O2). These molecules scatter the light in all directions, but they scatter shorter (blue) wavelengths more than longer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for token in llm.stream("why the sky is blue"):
#       2     print(token.content, flush=True, end="")
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:411, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     404 except BaseException as e:
#     405     run_manager.on_llm_error(
#     406         e,
#     407         response=LLMResult(
#     408             generations=[[generation]] if generation else []
#     409         ),
#     410     )
# --> 411     raise e
#     412 else:
#     413     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:391, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     388     self.rate_limiter.acquire(blocking=True)
#     390 try:
# --> 391     for chunk in self._stream(messages, stop=stop, **kwargs):
#     392         if chunk.message.id is None:
#     393             chunk.message.id = f"run-{run_manager.run_id}"
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/langchain_ollama/chat_models.py:663, in ChatOllama._stream(self, messages, stop, run_manager, **kwargs)
#     656 def _stream(
#     657     self,
#     658     messages: List[BaseMessage],
#    (...)
#     661     **kwargs: Any,
#     662 ) -> Iterator[ChatGenerationChunk]:
# --> 663     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     664         if not isinstance(stream_resp, str):
#     665             chunk = ChatGenerationChunk(
#     666                 message=AIMessageChunk(
#     667                     content=(
#    (...)
#     680                 ),
#     681             )
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/langchain_ollama/chat_models.py:525, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     515     yield self._client.chat(
#     516         model=params["model"],
#     517         messages=ollama_messages,
#    (...)
#     522         tools=kwargs["tools"],
#     523     )
#     524 else:
# --> 525     yield from self._client.chat(
#     526         model=params["model"],
#     527         messages=ollama_messages,
#     528         stream=True,
#     529         options=Options(**params["options"]),
#     530         keep_alive=params["keep_alive"],
#     531         format=params["format"],
#     532     )
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/ollama/_client.py:87, in Client._stream(self, method, url, **kwargs)
#      84   e.response.read()
#      85   raise ResponseError(e.response.text, e.response.status_code) from None
# ---> 87 for line in r.iter_lines():
#      88   partial = json.loads(line)
#      89   if e := partial.get('error'):
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpx/_models.py:863, in Response.iter_lines(self)
#     861 decoder = LineDecoder()
#     862 with request_context(request=self._request):
# --> 863     for text in self.iter_text():
#     864         for line in decoder.decode(text):
#     865             yield line
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpx/_models.py:850, in Response.iter_text(self, chunk_size)
#     848 chunker = TextChunker(chunk_size=chunk_size)
#     849 with request_context(request=self._request):
# --> 850     for byte_content in self.iter_bytes():
#     851         text_content = decoder.decode(byte_content)
#     852         for chunk in chunker.decode(text_content):
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpx/_models.py:831, in Response.iter_bytes(self, chunk_size)
#     829 chunker = ByteChunker(chunk_size=chunk_size)
#     830 with request_context(request=self._request):
# --> 831     for raw_bytes in self.iter_raw():
#     832         decoded = decoder.decode(raw_bytes)
#     833         for chunk in chunker.decode(decoded):
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpx/_models.py:885, in Response.iter_raw(self, chunk_size)
#     882 chunker = ByteChunker(chunk_size=chunk_size)
#     884 with request_context(request=self._request):
# --> 885     for raw_stream_bytes in self.stream:
#     886         self._num_bytes_downloaded += len(raw_stream_bytes)
#     887         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpx/_client.py:127, in BoundSyncStream.__iter__(self)
#     126 def __iter__(self) -> typing.Iterator[bytes]:
# --> 127     for chunk in self._stream:
#     128         yield chunk
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpx/_transports/default.py:116, in ResponseStream.__iter__(self)
#     114 def __iter__(self) -> typing.Iterator[bytes]:
#     115     with map_httpcore_exceptions():
# --> 116         for part in self._httpcore_stream:
#     117             yield part
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:367, in PoolByteStream.__iter__(self)
#     365 except BaseException as exc:
#     366     self.close()
# --> 367     raise exc from None
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:363, in PoolByteStream.__iter__(self)
#     361 def __iter__(self) -> Iterator[bytes]:
#     362     try:
# --> 363         for part in self._stream:
#     364             yield part
#     365     except BaseException as exc:
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpcore/_sync/http11.py:349, in HTTP11ConnectionByteStream.__iter__(self)
#     347 with ShieldCancellation():
#     348     self.close()
# --> 349 raise exc
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpcore/_sync/http11.py:341, in HTTP11ConnectionByteStream.__iter__(self)
#     339 try:
#     340     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 341         for chunk in self._connection._receive_response_body(**kwargs):
#     342             yield chunk
#     343 except BaseException as exc:
#     344     # If we get an exception while streaming the response,
#     345     # we want to close the response (and possibly the connection)
#     346     # before raising that exception.
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpcore/_sync/http11.py:210, in HTTP11Connection._receive_response_body(self, request)
#     207 timeout = timeouts.get("read", None)
#     209 while True:
# --> 210     event = self._receive_event(timeout=timeout)
#     211     if isinstance(event, h11.Data):
#     212         yield bytes(event.data)
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/github/langchain-academy/langgraph/lib/python3.12/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
